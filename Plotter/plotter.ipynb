# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import plotly as pl
import plotly.graph_objs as go
import cufflinks as cf
import plotly.offline as po
po.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def createData(data):
    if(data == 1):
        random_data = np.random.rand(100, 5)
        df = pd.DataFrame(random_data, columns=['A', 'B', 'C', 'D', 'E'])
        print("\n")
        print("\n")
        print("Random Data:")
        print(df.head())
    elif(data == 2):
        x = [0,0,0,0,0]
        r1 = [0,0,0,0,0]
        r2 = [0,0,0,0,0]
        r3 = [0,0,0,0,0]
        r4 = [0,0,0,0,0]
        print("Enter the values for columns")
        i = 0
        for i in [0,1,2,3,4]:
            x[i] = input()
            i = i + 1

        print("Enter the values for first row")
        i = 0
        for i in [0,1,2,3,4]:
            r1[i] = int(input())
            i = i + 1

        print("Enter the values for second row")
        i = 0
        for i in [0,1,2,3,4]:
            r2[i] = int(input())
            i = i + 1

        print("Enter the values for third row")
        i = 0
        for i in [0,1,2,3,4]:
            r3[i] = int(input())
            i = i + 1

        print("Enter the values for fourth row")
        i = 0
        for i in [0,1,2,3,4]:
            r4[i] = int(input())
            i = i + 1
        df = pd.DataFrame([r1,r2,r3,r4], columns=x)
        print("\n")
        print("\n")
        print("Customized Data:")
        print(df.head())
    elif(data == 3):
        input_file = input("Enter the file name with extension: ")
        df = pd.read_csv(input_file)
        file_dataFrame = pd.DataFrame(df)
        print("\n")
        print("\n")
        print("File Data:")
        print(file_dataFrame.head())
    else:
        print("Invalid input! DataFrame Creation Failed")
    # return df

# %%
def plotter(plot):
    if(plot == 1):
        finalOutpt = df.iplot(kind='line')
    elif(plot == 2):
        finalOutpt = df.iplot(kind='bar', barmode='stack')
    elif(plot == 3):
        finalOutpt = df.iplot(kind='scatter', mode='markers', symbol='x')
    elif(plot == 4):
        finalOutpt = df.iplot(kind='box')
    elif(plot == 5):
        finalOutpt = df.iplot(kind='hist')
    elif(plot == 6):
        finalOutpt = df.iplot(kind='surface')
    else:
        print("Invalid input! Plotting Failed")
    return finalOutpt

# %%
def plotter2(plot):
    if(plot == 1):
        finalOutpt = df.iplot(kind='line')
    elif(plot == 2):
        finalOutpt = df.iplot(kind='bar')
    elif(plot == 3):
        finalOutpt = df.iplot(kind='scatter')
    elif(plot == 4):
        finalOutpt = df.iplot(kind='box')
    elif(plot == 5):
        finalOutpt = df.iplot(kind='hist')
    elif(plot == 6):
        finalOutpt = df.iplot(kind='surface')
    elif(plot == 7):
        finalOutpt = df.iplot(kind='bubble')
    else:
        print("Invalid input! Plotting Failed")
    return finalOutpt

# %%
def plotData(cat):
    if(cat == 1):
        print("Select the type of plot you want to create from option 1-6")
        print("1. Line Plot")
        print("2. Bar Plot")
        print("3. Scatter Plot")
        print("4. Box Plot")
        print("5. Histogram Plot")
        print("6. Surface Plot")
        plot_type = int(input())
        output = plotter(plot_type)
    elif(cat == 2):
        print("Select the type of plot you want to create from option 1-6")
        print("1. Line Plot")
        print("2. Bar Plot")
        print("3. Scatter Plot")
        print("4. Box Plot")
        print("5. Histogram Plot")
        print("6. Surface Plot")
        print("7. Bubble Plot")
        plot_type = input()
        output = plotter2(plot_type)
    else:
        print("Invalid input! Plot Creation Failed")

# %%
# Creating data
print("Select the type of data to be plotted. Select from 1,2,3")
print("1. Random Data with 5 columns")
print("2. Customized Data with 5 cols and 4 rows") 
print("3. Upload your own data in csv/json/txt format")
user_input = int(input("Enter your choice: "))
df1 = createData(user_input)
# Out:
# Select the type of data to be plotted. Select from 1,2,3
# 1. Random Data with 5 columns
# 2. Customized Data with 5 cols and 4 rows
# 3. Upload your own data in csv/json/txt format
#
#
#
#
# Random Data:
#           A         B         C         D         E
# 0  0.064912  0.788842  0.596020  0.309609  0.190668
# 1  0.867272  0.533924  0.610194  0.198736  0.095528
# 2  0.540666  0.611269  0.623535  0.747806  0.188307
# 3  0.467843  0.959944  0.379761  0.033586  0.194174
# 4  0.784256  0.476863  0.383056  0.390809  0.154946

# %%
# Plotting data
print("What kind of plot do you need? Complete data plot or column wise plot?")
cat = int(input("Enter 1 for complete data plot and 2 for column wise plot: "))
# Out:
# What kind of plot do you need? Complete data plot or column wise plot?

# %%
plotData(cat)
# Out:
# Select the type of plot you want to create from option 1-6
# 1. Line Plot
# 2. Bar Plot
# 3. Scatter Plot
# 4. Box Plot
# 5. Histogram Plot
# 6. Surface Plot
# <div>                            <div id="a8c81997-dbe0-48e3-875d-0d7c3f679336" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a8c81997-dbe0-48e3-875d-0d7c3f679336")) {                    Plotly.newPlot(                        "a8c81997-dbe0-48e3-875d-0d7c3f679336",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"A","orientation":"v","y":[0.5357921995970832,0.6343348121351488,0.29164751889435536,0.25659775351374936,0.5513852904610057,0.9266072041028683,0.8954583063597453,0.379578566898243,0.44954831697256037,0.39781095216613116,0.030924546665569874,0.1277530864090376,0.6784745180942344,0.639494255168095,0.9483466233449606,0.2400160553472156,0.8225332932548556,0.4725645146101466,0.45220034833817335,0.30709378246744634,0.06522230732748369,0.03511958671617632,0.016874703226283594,0.06043494545348638,0.10119550673440791,0.23097036847495078,0.211316275130623,0.2950086098783752,0.18783299340897353,0.4372209880510559,0.8634821243186359,0.17364786215631622,0.9600585691519495,0.8340097156515416,0.738284899359069,0.01504388022487324,0.3353760631882844,0.9